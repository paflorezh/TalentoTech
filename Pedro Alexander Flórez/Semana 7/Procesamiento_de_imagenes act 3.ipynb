# %% [markdown]
# Procesamiento de imagenes OpenCV

# %% [markdown]
# Instalacion de librerias

# %%
pip install opencv-python

# %% [markdown]
# Importación de las librerias

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# Carga de la imagen desde el archivo (en colab no sirve esta funcion?, sugerencia de gemini importar libreria cv2_imshow y ajusta el codigo de la siguente manera)

# %%
image = cv2.imread('imagen1.jpg')

cv2_imshow(image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x425>

# %% [markdown]
# Rotacion de la imagen.

# %%
image = cv2.imread('imagen1.jpg')

height, width = image.shape[:2]

center = (width/2, height/2)

angle = 45
M = cv2.getRotationMatrix2D(center, angle, 1.0)

rotated = cv2.warpAffine(image, M, (width, height))

cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=600x425>

# %% [markdown]
# Traslacion de imagenes

# %%
tx, ty = 100, 50
M = np.float32([[1, 0, tx], [0, 1, ty]])

#aplicar la translacion

#translated = cv2.warpAffine(image, M, image.shape[1], image.shape[0])

#Error al representar el tamaño de la imagen suguerencia realizada por gemini

translated = cv2.warpAffine(image, M, (width, height))

cv2_imshow(translated)
# Out:
# <PIL.Image.Image image mode=RGB size=600x425>

# %% [markdown]
# Escala de imagenes

# %%
new_width, new_height = 400, 200

#aplicar la nueva escala de la imagen

scaled = cv2.resize(image, (new_width, new_height))

cv2_imshow(scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# Suavizado de imagenes

# %%
smoothed = cv2.GaussianBlur(image, (5,5),0)

cv2_imshow(smoothed)
# Out:
# <PIL.Image.Image image mode=RGB size=600x425>

# %% [markdown]
# Realce de imagenes

# %%
kernel = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])
sharpened = cv2.filter2D(image, -1, kernel)

cv2_imshow(sharpened)
# Out:
# <PIL.Image.Image image mode=RGB size=600x425>

# %% [markdown]
# Detención de bordes de imagenes

# %%
image = cv2.imread('imagen1.jpg', cv2.IMREAD_GRAYSCALE)

sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize = 5)
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize = 5)

edges = cv2.magnitude(sobelx, sobely)

edges = cv2.normalize(edges, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)

cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=600x425>
